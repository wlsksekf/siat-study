# %% [markdown]
# ---
# ### 2차원 리스트를 데이터프레임으로 변환

# %%
score=[['정약용', 70, 80, 100],
       ['이순신', 100, 80, 70],
       ['이율곡', 90, 95, 90]]
print(type(score))
print(score)
# Out:
# <class 'list'>
# [['정약용', 70, 80, 100], ['이순신', 100, 80, 70], ['이율곡', 90, 95, 90]]

# %% [markdown]
# ---
# DataFrame으로 바꾸기

# %%
import pandas as pd
score_df = pd.DataFrame(score)

print(type(score_df))
print(score_df)
# Out:
# <class 'pandas.DataFrame'>
#      0    1   2    3
# 0  정약용   70  80  100
# 1  이순신  100  80   70
# 2  이율곡   90  95   90

# %% [markdown]
# ---
# 아래와 같이 출력되도록 합니다

# %%
print(score_df)
# Out:
#      0    1   2    3
# 0  정약용   70  80  100
# 1  이순신  100  80   70
# 2  이율곡   90  95   90

# %% [markdown]
# ---
# 아래와 같이 출력되도록 합니다

# %%
import pandas as pd

score = [
    ['홍길동', 70, 80, 100],
    ['이순신', 100, 80, 70],
    ['강감찬', 90, 95, 90]
]

score_df = pd.DataFrame(score, columns=['이름', '국어', '영어', '수학'])

print(type(score_df))
score_df.info()
# Out:
# <class 'pandas.DataFrame'>
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      3 non-null      str
#  1   국어      3 non-null      int64
#  2   영어      3 non-null      int64
#  3   수학      3 non-null      int64
# dtypes: int64(3), str(1)
# memory usage: 228.0 bytes

# %%
# 원본 복사
score_df_copy = score_df.copy()

# %% [markdown]
# ---
# 이름이 이순신 인지 비교

# %%
print(score_df_copy['이름'] == '이순신')
# Out:
# 0    False
# 1     True
# 2    False
# Name: 이름, dtype: bool

# %% [markdown]
# ---
# 이름이 이순신인 행 출력

# %%
print(score_df_copy[score_df_copy['이름'] == '이순신'])
# Out:
#     이름   국어  영어  수학
# 1  이순신  100  80  70

# %% [markdown]
# ---
# 이름이 이순신인 행의 index 구하기

# %%
idx = score_df_copy[score_df_copy['이름'] == '이순신'].index
print(idx)
# Out:
# RangeIndex(start=1, stop=2, step=1)

# %% [markdown]
# ---
# 이름이 이순신인 행 삭제하기

# %%
result = score_df_copy.drop(index=idx)

# %%
print(result)
# Out:
#     이름  국어  영어   수학
# 0  홍길동  70  80  100
# 2  강감찬  90  95   90

# %% [markdown]
# ---
# 수학 컬럼 삭제하기

# %%
score_df_copy = score_df_copy.drop(columns=['수학'])
print(score_df_copy)
# Out:
#     이름   국어  영어
# 0  홍길동   70  80
# 1  이순신  100  80
# 2  강감찬   90  95

# %% [markdown]
# ---
# 과학 컬럼을 국어 앞에 추가하기

# %%
score_df_copy.insert(1, column="과학", value=[80, 90, 86])
print(score_df_copy)
# Out:
#     이름  과학   국어  영어
# 0  홍길동  80   70  80
# 1  이순신  90  100  80
# 2  강감찬  86   90  95
