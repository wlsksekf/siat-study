# %%
import pandas as pd

favorite = pd.Series(['WINTER', 'SUMMER', 'SPRING', 'SUMMER', 'SUMMER',
                    'FALL', 'FALL', 'SUMMER', 'SPRING', 'SPRING'])
print(favorite)
# Out:
# 0    WINTER
# 1    SUMMER
# 2    SPRING
# 3    SUMMER
# 4    SUMMER
# 5      FALL
# 6      FALL
# 7    SUMMER
# 8    SPRING
# 9    SPRING
# dtype: str

# %%
fd = favorite.value_counts()
print(type(fd))
# Out:
# <class 'pandas.Series'>

# %%
print(fd)
# Out:
# SUMMER    4
# SPRING    3
# FALL      2
# WINTER    1
# Name: count, dtype: int64

# %%
print(fd['SUMMER'])
print(fd.iloc[0])
# Out:
# 4
# 4

# %% [markdown]
# ## 도수분포표
#
# ### 도수분포표란 데이터를 일정한 구간으로 나누고, 각 구간에 속한 데이터의 개수를 정리한 표이다.
#
# - 막대 그래프
# - 히스토그램
# - 원 그래프

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\github\siat-study\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\github\siat-study\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\github\siat-study\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\github\siat-study\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\github\siat-study\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\github\siat-study\.venv\lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\github\siat-study\.venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\github\siat-study\.venv\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\github\siat-study\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\github\siat-study\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\github\siat-study\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

fd.plot.bar(xlabel='Season')

plt.show()

# %%
fd.plot.bar(xlabel='Season',
            rot=0)
plt.show()

# %%
fd.plot.bar(xlabel='Season',
            ylabel='Frequency',
            rot=0,
            title='Favorite Season')
plt.show()

# %%
fd.plot.barh(xlabel='Frequency',
            ylabel='Season',
            rot=0,
            title='Favorite Season')
plt.show()

# %%
fd.plot.pie()

plt.show()

# %%
fd.plot.pie(autopct='%1.0f%%',
            title='Favorite Season')
plt.show()

# %%
colors = pd.Series([20, 30, 20, 10, 10, 20, 20, 10, 30, 20, 10, 30, 20, 10, 20])

fd = colors.value_counts()
print(fd)
# Out:
# 20    7
# 10    5
# 30    3
# Name: count, dtype: int64

# %%
print(colors.value_counts()/colors.size)
# Out:
# 20    0.466667
# 10    0.333333
# 30    0.200000
# Name: count, dtype: float64

# %%
print(fd.index)
# Out:
# Index([20, 10, 30], dtype='int64')

# %%
fd.index = ['red', 'green', 'blue']
print(fd)
# Out:
# red      7
# green    5
# blue     3
# Name: count, dtype: int64

# %%
fd.plot.bar(xlabel='Color',
            ylabel='Frequency',
            rot=0,
            title='Favorite Color')
plt.show()

# %%
fd.plot.pie(autopct='%1.0f%%',
            title='Favorite Color')
plt.show()

# %%
fd.plot.pie(autopct='%1.0f%%',
            title='Favorite Color',
            colors=['red', 'green', 'blue'])
plt.show()

# %%
ds = [60, 62, 64, 65, 68, 69]
weight = pd.Series(ds)

# %%
ds.append(120)
weight_heavy = pd.Series(ds)

# %%
print(weight)
# Out:
# 0    60
# 1    62
# 2    64
# 3    65
# 4    68
# 5    69
# dtype: int64

# %%
print(weight_heavy)
# Out:
# 0     60
# 1     62
# 2     64
# 3     65
# 4     68
# 5     69
# 6    120
# dtype: int64

# %%
print(weight.mean())
print(weight_heavy.mean())
# Out:
# 64.66666666666667
# 72.57142857142857

# %%
print(weight.median())
print(weight_heavy.median())
# Out:
# 64.5
# 65.0

# %%
# %pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\github\siat-study\.venv\lib\site-packages (1.17.0)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in c:\github\siat-study\.venv\lib\site-packages (from scipy) (2.4.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scipy import stats
print(stats.trim_mean(weight, 0.2))
print(stats.trim_mean(weight_heavy, 0.2))
# Out:
# 64.75
# 65.6

# %%
import pandas as pd
import numpy as np

mydata = [60, 62, 64, 65, 68, 69, 120]
mydata = pd.Series(mydata)

# %%
q1 = mydata.quantile(0.25)
print(q1)
# Out:
# 63.0

# %%
q2 = mydata.quantile(0.5)
print(q2)
# Out:
# 65.0

# %%
q3 = mydata.quantile(0.75)
print(q3)
# Out:
# 68.5

# %%
q4 = mydata.quantile([0.25, 0.5, 0.75])
print(q4)
# Out:
# 0.25    63.0
# 0.50    65.0
# 0.75    68.5
# dtype: float64

# %%
mydata.describe()
# Out:
# count      7.000000
# mean      72.571429
# std       21.149130
# min       60.000000
# 25%       63.000000
# 50%       65.000000
# 75%       68.500000
# max      120.000000
# dtype: float64

# %%
mydata = pd.Series([60, 62, 64, 65, 68, 69, 72])

print(mydata.var())
print(mydata.std())
# Out:
# 17.57142857142857
# 4.191828786034631

# %%
df = pd.read_csv('data/cars.csv')
dist = df['dist']
print(type(dist))
print(dist)
# Out:
# <class 'pandas.Series'>
# 0       2
# 1      10
# 2       4
# 3      22
# 4      16
# 5      10
# 6      18
# 7      26
# 8      34
# 9      17
# 10     28
# 11     14
# 12     20
# 13     24
# 14     28
# 15     26
# 16     34
# 17     34
# 18     46
# 19     26
# 20     36
# 21     60
# 22     80
# 23     20
# 24     26
# 25     54
# 26     32
# 27     40
# 28     32
# 29     40
# 30     50
# 31     42
# 32     56
# 33     76
# 34     84
# 35     36
# 36     46
# 37     68
# 38     32
# 39     48
# 40     52
# 41     56
# 42     64
# 43     66
# 44     54
# 45     70
# 46     92
# 47     93
# 48    120
# 49     85
# Name: dist, dtype: int64

# %%
dist.plot.hist()
plt.show()

# %%
result = dist.value_counts(bins=10, sort=False)
print(result)
# Out:
# (1.881, 13.8]      4
# (13.8, 25.6]       8
# (25.6, 37.4]      14
# (37.4, 49.2]       6
# (49.2, 61.0]       7
# (61.0, 72.8]       4
# (72.8, 84.6]       3
# (84.6, 96.4]       3
# (96.4, 108.2]      0
# (108.2, 120.0]     1
# Name: count, dtype: int64

# %%
print(dist.min())
print(dist.max())
# Out:
# 2
# 120

# %%
result = dist.value_counts(bins=6, sort=False)
print(result)
# Out:
# (1.881, 21.667]      10
# (21.667, 41.333]     18
# (41.333, 61.0]       11
# (61.0, 80.667]        6
# (80.667, 100.333]     4
# (100.333, 120.0]      1
# Name: count, dtype: int64

# %%
df = pd.read_csv('data/cars.csv')
dist = df['dist']

dist.plot.box(title='Breaking distance')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('data/iris.csv')

df.boxplot(column='Petal_Length',
        by='Species',
        grid=False)
plt.show()

# %%
favorite = pd.Series(['WINTER', 'SUMMER', 'SPRING', 'SUMMER', 'SUMMER',
                    'FALL', 'FALL', 'SUMMER', 'SPRING', 'SPRING'])

fd = favorite.value_counts()

fd.plot.bar(xlabel='Season',
            ylabel='Frequency',
            rot=30,
            title='Favorite Season',
            color='b',
            grid=True,
            figsize=(3, 2)
            )

plt.show()

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

ser = pd.Series([3, 1, 1, 2])

result = ser.value_counts().sort_index()
print(result)
# Out:
# 1    2
# 2    1
# 3    1
# Name: count, dtype: int64

# %%
result.plot.bar(rot=0)

plt.title('그래프 예제 - 막대 그래프')
plt.show()

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = True

ser = pd.Series([-5, -3, -1, 0, 1, 3, 5])
ser.plot(title='음수 깨짐 확인 그래프')

plt.show()
# Out:
# c:\github\siat-study\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df = pd.read_csv('data/iris.csv')

fig, axes = plt.subplots(nrows=2, ncols=2)

df['Petal_Length'].plot.hist(ax=axes[0, 0])

df['Petal_Length'].plot.box(ax=axes[0, 1])

fd = df['Species'].value_counts()
fd.plot.pie(ax=axes[1, 0], ylabel='')
fd.plot.barh(ax=axes[1, 1], ylabel='')

fig.suptitle('Multiple Graph Example', fontsize=14)
plt.show()
